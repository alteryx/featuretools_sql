# %%
from featuretools_sql.connector import DBConnector
import pandas as pd
import psycopg2
import pytest
import testing.postgresql
from featuretools import EntitySet

# %%
es = ft.demo.load_retail()
engine = create_engine("postgresql://postgres:postgres@localhost:5432/postgres")
for df in es.dataframes: 
    name = df.ww.name
    idx_col = df.ww.index
    df.to_sql(name, engine, index=False)
    with engine.connect() as con:
        rs = con.execute(f"ALTER TABLE public.{name} add primary key ({idx_col})")
with engine.connect() as con:
    con.execute(
        f"ALTER TABLE public.order_products ADD CONSTRAINT fk FOREIGN KEY (product_id) REFERENCES products (product_id) MATCH FULL"
    )
    con.execute(
        f"ALTER TABLE public.order_products ADD CONSTRAINT fk1 FOREIGN KEY (order_id) REFERENCES orders (order_id) MATCH FULL"
    )
    con.execute(
        f"ALTER TABLE public.orders ADD CONSTRAINT fk2 FOREIGN KEY (customer_name) REFERENCES customers (customer_name) MATCH FULL"
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_l/yz48js3s4ss9z933356vff0w0000gq/T/ipykernel_5650/355676670.py in <module>
#       1 es = ft.demo.load_retail()
# ----> 2 engine = create_engine("postgresql://postgres:postgres@localhost:5432/postgres")
#       3 for df in es.dataframes:
#       4     name = df.ww.name
#       5     idx_col = df.ww.index
#
# NameError: name 'create_engine' is not defined

# %%
from featuretools_sql.connector import DBConnector

connector_object = DBConnector(system_name="postgresql", 
                               user="postgres", 
                               host="localhost", 
                               port="5432", 
                               database="postgres", 
                               schema="public")

# %%
es = connector_object.get_entityset()
# Out:
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/.pyenv/versions/3.8.12_x86/envs/venv_x86/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /Users/shripad.badithe/featuretoolsclone/featuretools/featuretools/entityset/entityset.py:414: UserWarning: Logical type Categorical for child column product_id does not match parent column product_id logical type Unknown. Changing child logical type to match parent.
#   warnings.warn(
# /Users/shripad.badithe/featuretoolsclone/featuretools/featuretools/entityset/entityset.py:414: UserWarning: Logical type Categorical for child column order_id does not match parent column order_id logical type Unknown. Changing child logical type to match parent.
#   warnings.warn(
# /Users/shripad.badithe/featuretoolsclone/featuretools/featuretools/entityset/entityset.py:414: UserWarning: Logical type Categorical for child column customer_name does not match parent column customer_name logical type Unknown. Changing child logical type to match parent.
#   warnings.warn(

# %%
list(es.dataframe_dict.keys())
# Out:
# ['orders', 'customers', 'products', 'order_products']

# %%
es.dataframe_dict["products"].head(5)
# Out:
#        product_id                          description  \
# 85123A     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 71053       71053                  WHITE METAL LANTERN
# 84406B     84406B       CREAM CUPID HEARTS COAT HANGER
# 84029G     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 84029E     84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#        first_order_products_time       _ft_last_time
# 85123A       2010-12-01 08:26:00 2011-12-09 11:34:00
# 71053        2010-12-01 08:26:00 2011-12-07 14:12:00
# 84406B       2010-12-01 08:26:00 2011-12-05 14:30:00
# 84029G       2010-12-01 08:26:00 2011-12-09 11:26:00
# 84029E       2010-12-01 08:26:00 2011-12-09 09:07:00

# %%
es.relationships
# Out:
# [<Relationship: order_products.product_id -> products.product_id>,
#  <Relationship: order_products.order_id -> orders.order_id>,
#  <Relationship: orders.customer_name -> customers.customer_name>]

# %%
import featuretools as ft

# %%
fm, feats = ft.dfs(entityset=es,
                target_dataframe_name="order_products")

# %%
feats[:5]
# Out:
# [<Feature: order_id>,
#  <Feature: product_id>,
#  <Feature: quantity>,
#  <Feature: unit_price>,
#  <Feature: total>]

# %%
fm[:5]
# Out:
#                  order_id product_id  quantity  unit_price   total  \
# order_product_id
# 0                  536365     85123A         6      4.2075  25.245
# 1                  536365      71053         6      5.5935  33.561
# 2                  536365     84406B         8      4.5375  36.300
# 3                  536365     84029G         6      5.5935  33.561
# 4                  536365     84029E         6      5.5935  33.561
#
#                  DAY(order_date) MONTH(order_date) WEEKDAY(order_date)  \
# order_product_id
# 0                              1                12                   2
# 1                              1                12                   2
# 2                              1                12                   2
# 3                              1                12                   2
# 4                              1                12                   2
#
#                  YEAR(order_date) orders.customer_name  ...  \
# order_product_id                                        ...
# 0                            2010         Andrea Brown  ...
# 1                            2010         Andrea Brown  ...
# 2                            2010         Andrea Brown  ...
# 3                            2010         Andrea Brown  ...
# 4                            2010         Andrea Brown  ...
#
#                  orders.STD(order_products.quantity)  \
# order_product_id
# 0                                           1.799471
# 1                                           1.799471
# 2                                           1.799471
# 3                                           1.799471
# 4                                           1.799471
#
#                   orders.STD(order_products.total)  \
# order_product_id
# 0                                          5.97451
# 1                                          5.97451
# 2                                          5.97451
# 3                                          5.97451
# 4                                          5.97451
#
#                   orders.STD(order_products.unit_price)  \
# order_product_id
# 0                                              2.866571
# 1                                              2.866571
# 2                                              2.866571
# 3                                              2.866571
# 4                                              2.866571
#
#                   orders.SUM(order_products.quantity)  \
# order_product_id
# 0                                                40.0
# 1                                                40.0
# 2                                                40.0
# 3                                                40.0
# 4                                                40.0
#
#                   orders.SUM(order_products.total)  \
# order_product_id
# 0                                          229.548
# 1                                          229.548
# 2                                          229.548
# 3                                          229.548
# 4                                          229.548
#
#                   orders.SUM(order_products.unit_price)  \
# order_product_id
# 0                                               45.1605
# 1                                               45.1605
# 2                                               45.1605
# 3                                               45.1605
# 4                                               45.1605
#
#                   orders.DAY(first_order_products_time)  \
# order_product_id
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
#
#                   orders.MONTH(first_order_products_time)  \
# order_product_id
# 0                                                      12
# 1                                                      12
# 2                                                      12
# 3                                                      12
# 4                                                      12
#
#                   orders.WEEKDAY(first_order_products_time)  \
# order_product_id
# 0                                                         2
# 1                                                         2
# 2                                                         2
# 3                                                         2
# 4                                                         2
#
#                   orders.YEAR(first_order_products_time)
# order_product_id
# 0                                                   2010
# 1                                                   2010
# 2                                                   2010
# 3                                                   2010
# 4                                                   2010
#
# [5 rows x 64 columns]
